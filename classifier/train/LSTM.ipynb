# %%
# !pip install janome
# Out:
# Requirement already satisfied: janome in /usr/local/lib/python3.7/dist-packages (0.4.1)

# %%
import os,sys
import json
import numpy as np
import pandas as pd

from janome.tokenizer import Tokenizer
import re

import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
import torch.autograd as autograd
from torch.utils.data import DataLoader

from torchtext.legacy import data
from torchtext.legacy import datasets
from torchtext.vocab import FastText
import torchtext.legacy as torchtext

from sklearn.model_selection import train_test_split

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !nvidia-smi
# Out:
# Sat Sep 11 09:53:12 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 470.63.01    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla K80           Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   49C    P8    26W / 149W |      0MiB / 11441MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
# 訓練に使用するデバイス
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print('Using {} device'.format(device))
# Out:
# Using cuda device

# %%
# dataclean 
# 参考 : 
# 1.https://qiita.com/Hironsan/items/2466fe0f344115aff177
# 2.https://www.oio-blog.com/contents/preprocessing
# tokenizerの定義
def clean_tokenizer(text):
  j_t = Tokenizer()
  # 記号除去
  pattern = '[!"#$%&\'\\\\()*+,-./:;<=>?@[\\]^_`{|}~「」〔〕“”◇ᴗ●↓→♪★⊂⊃※△□◎〈〉『』【】＆＊・（）＄＃＠。、？！｀＋￥％＞＜]'
  text = re.sub(pattern, '', text)
  return [tok for tok in j_t.tokenize(text, wakati=True)]

# test
print(clean_tokenizer("お姉さんはお元気ですか、スティーブ。"))
# Out:
# ['お', '姉さん', 'は', 'お', '元気', 'です', 'か', 'スティーブ']

# %%
def label_preprocessing(label):
  if label == 'how':
    return 0
  elif label == 'what':
    return 1
  elif label == 'when':
    return 2
  elif label == 'where':
    return 3
  elif label == 'who':
    return 4
  elif label == 'why':
    return 5
  elif label == 'plain':
    return 6
  elif label == 'please':
    return 7
  else:
    return 8

# %%
# Dataset(train_dataset)のFieldを定義
text_field = torchtext.data.Field(
    init_token = '<SOS>',
    eos_token = '<EOS>',
    use_vocab = True,
    lower = True,
    tokenize = clean_tokenizer,
    is_target = False
)
# Dataset(test_dataset)のFieldを定義
label_field = torchtext.data.Field(
    sequential = False,
    use_vocab = False,
    preprocessing = torchtext.data.Pipeline(label_preprocessing),
    is_target = True
)

# csvファイルのロード
dataset = torchtext.data.TabularDataset(
    path = "drive/My Drive/kenkyu/data/data_augment.csv",
    format = 'csv',
    fields = [('data', text_field), ('label', label_field)],
    skip_header = False
)
# train_dataset : 5955
# test_dataset : 1489
train_dataset, test_dataset = dataset.split(
    split_ratio = 0.8
)
print('train_dataset : {}'.format(len(train_dataset)))
print('test_dataset : {}'.format(len(test_dataset)))
# Out:
# train_dataset : 5950
# test_dataset : 1488

# %%
# vocabularyの作成
# 学習済み単語分散表現としてFastTextを使用
text_field.build_vocab(train_dataset, vectors = FastText(language = 'ja'), min_freq = 2)
text_field.vocab.vectors.size()
# Out:
# torch.Size([2529, 300])

# %%
# integer to string 辞書
print(text_field.vocab.itos)
# string to integer 辞書
print(text_field.vocab.stoi)
# 単語カウント結果
print(text_field.vocab.freqs)
# vectors
print(text_field.vocab.vectors)
# size of vectors
text_field.vocab.vectors.size()
# train_data
for idx in range(10):
  print('label : {0}, data : {1}'.format(vars(train_dataset[idx])['label'], vars(train_dataset[idx])['data']))
# Out:
# ['<unk>', '<pad>', '<SOS>', '<EOS>', 'の', 'は', 'か', 'に', 'を', 'て', 'た', 'です', 'が', 'ます', 'し', 'どこ', 'ん', 'で', 'な', 'どう', 'いる', 'と', '何', 'い', 'だれ', 'う', 'こと', 'だ', 'あなた', 'ない', 'いつ', 'する', 'たち', 'いい', 'この', 'つ', 'も', 'ある', 'お', 'から', 'たら', '私', 'よ', 'でしょ', 'わたし', '人', 'だい', 'それ', 'ませ', 'まし', 'いただけ', 'へ', 'その', 'どうして', 'ね', 'たい', 'かしら', 'だっ', 'なぜ', 'これ', 'よう', 'どんな', 'だろ', 'ここ', 'さん', 'くれ', 'ば', 'どの', 'やっ', 'あり', 'もらえ', '彼', '行く', '行っ', '誰', 'なっ', 'って', 'について', 'まで', 'ぼく', '彼女', 'れ', '言っ', '来', 'あの', 'でき', 'くらい', 'ご', 'さ', 'なかっ', '行き', '今', 'どういう', 'もの', '時', '自分', '時間', '君', 'ため', 'できる', 'でし', '1', 'いかが', '思い', 'そう', '教え', 'くれる', 'み', 'わ', '的', 'かい', '好き', '見', 'られ', 'いっしょ', 'お願い', '仕事', '日本', '\u3000', 'きみ', 'き', '話し', '電話', 'なり', '先生', 'アメリカ', '新しい', '…', 'だけ', '思う', '持っ', '日', '次', '写真', 'いくら', 'てる', 'ほか', 'そこ', 'や', '必要', '知っ', 'とき', 'なく', 'という', 'ましょ', 'られる', '中', '店', 'なる', '前', '家', '何で', '意味', '話', 'じゃ', '手', '書い', '食べ', ' ', 'すれ', 'ところ', '者', 'ちゃん', 'つもり', 'でも', '僕', '映画', '住ん', 'ください', 'ちょっと', 'どちら', 'もう少し', 'もっと', '始まる', '彼ら', '聞い', 'どれ', 'もう', '女の子', '思っ', '練習', '行か', '見つけ', '買っ', 'くる', 'けど', 'よく', 'メール', '始め', '智美', 'そんな', 'とても', '説明', 'ござる', '帰っ', '建て', '部屋', 'っけ', 'べき', 'みんな', '入れ', '出身', '考え', '2', 'いつも', 'お父さん', '方', '本', '試合', 'あっ', 'いけ', 'わかる', 'ロボコーパス', '両親', '料理', '来る', 'そんなに', 'なら', 'なんで', '最初', 'こんな', '問題', '姉ちゃん', '皆さん', '見え', '3', 'あと', 'なん', 'れる', 'パーティー', '名前', '旅行', '最後', '置い', '翔', 'いっ', 'きょう', 'しまっ', 'また', 'もう一度', 'コンテスト', '予定', '伝え', '作っ', '場所', '学校', '尋ね', '英語', '食べる', 'あれ', 'いくつ', 'として', 'ふたり', 'まだ', '今日', '元気', '出', '夏', '席', '本当に', '祭', 'あげ', 'いったい', 'こんなに', 'さま', 'す', 'たり', 'どなた', 'より', 'わかっ', 'わかり', 'コーヒー', '公園', '具体', '出る', '勉強', '少し', '結果', '聞く', '見せ', '言う', '週末', '陽', '駅', 'しよ', 'なけれ', 'よい', 'チョコレート', '一', '一緒', '先輩', '参加', '年', '感じ', '感謝', '買える', '車', 'あやめ', 'うまく', 'お母さん', 'せ', 'ほしい', 'レッスン', '助け', '図書館', '所', '撮っ', '様', '物', '着', '競技', '記事', '部', 'いちばん', 'え', 'これから', 'ので', 'ほう', 'もらえる', 'バッグ', '会社', '入っ', '出発', '向かっ', '向こう', '君たち', '回', '大きな', '待っ', '演奏', '用', '答え', '見る', '貸し', '間', '雄平', '5', 'いか', 'いく', 'うち', 'かかっ', 'それら', 'みたい', 'オープン', 'レストラン', '一体', '今年', '休暇', '会議', '劇', '場合', '屋', '悪い', '最も', '朝食', '欲しい', '発表', '読ん', '質問', '10', 'かかり', 'そして', 'たくさん', 'オーディション', 'クリス', 'チーム', 'ティノ', 'ノート', 'ルナ', '同じ', '土曜日', '声', '多く', '夜', '家族', '手伝っ', '日曜日', '末', '歳', '気に入っ', '気分', '目', '科学', '言い', '誘っ', '調子', '送っ', '重要', '関係', 'あげる', 'いつお', 'おまえ', 'かけ', 'ぐらい', 'けれど', 'ずっと', 'そういう', 'つい', 'とっ', 'なんて', 'インタビュー', 'サッカー', 'ダンス', 'ツアー', 'デート', 'ユキチ', 'ロボット', '人気', '何と', '具合', '友達', '外', '大会', '太', '子ども', '子供', '度', '座っ', '携帯', '教室', '数', '母さん', '確認', '秘密', '種類', '職場', '自転車', '行け', '見える', '試し', '連れ', '隣', '食べ物', '飲み', '高校', 'かかる', 'かも', 'それとも', 'たく', 'なさい', 'など', 'ほど', 'もどっ', 'もらっ', 'やる', 'よろしい', 'アドバイス', 'クリスマス', 'ケーキ', 'ミキ', 'モニカ', '世代', '今週', '使う', '使っ', '出し', '実は', '思わ', '性', '撮影', '早く', '最近', '気', '生活', '美樹', '聞き', '衣装', '詳しく', '誕生', '過ごし', '道場', '顧客', 'きのう', 'くん', 'ころ', 'しれ', 'じゃあ', 'すみません', 'なんか', 'ら', 'ジュース', 'テレビ', 'デービッド', 'ヒロ', '上演', '人間', '今夜', '企業', '会っ', '出かける', '分', '初めて', '匠', '反応', '受け', '城主', '夢', '始まっ', '将来', '応援', '担当', '書く', '月', '気持ち', '注文', '準備', '父', '状況', '番号', '皿', '相手', '終わっ', '部門', '雪', 'おっしゃっ', 'せる', 'だって', 'つけ', 'とにかく', 'ふう', 'ほとんど', 'まあ', 'もし', 'やめ', 'よかっ', 'わけ', 'イギリス', 'イベント', 'オフィス', 'コンサート', 'ソーニャ', 'チェック', 'チキン', 'データ', 'プレゼント', 'プロジェクト', '上がっ', '人々', '使わ', '係', '健康', '向け', '大好き', '始める', '心配', '息子', '手紙', '旅館', '明日', '時代', '正確', '水', '男の子', '知り', '石', '立っ', '締め切り', '行ける', '覚え', '財布', '買え', '赤い', '都合', '長く', '飲み物', '麻衣子', 'あした', 'いらっしゃい', 'おい', 'おれ', 'がた', 'こ', 'しかた', 'すべて', 'ながら', 'にとって', 'わから', 'アイデア', 'カイル', 'クローディア', 'サイズ', 'ジャケット', 'スーツケース', 'テーブル', 'デビュー', 'トイレ', 'プロポーズ', 'ママ', 'マラソン', 'メッセージ', '主', '今度', '代わり', '会い', '会える', '作る', '取っ', '取る', '取扱', '可能', '夏休み', '外国', '姉さん', '始まり', '娘', '子', '学生', '対応', '尊敬', '捜し', '文化', '方法', '書', '桜山', '決め', '理由', '生まれ', '知ら', '社', '祝わ', '秋祭り', '緊張', '聞こえ', '興味', '言わ', '課題', '責任', '買う', '返し', '連絡', '週間', '遺失', '部分', '野球', '長 ...
# defaultdict(<bound method Vocab._default_unk_index of <torchtext.legacy.vocab.Vocab object at 0x7f4a65a9fc50>>, {'<unk>': 0, '<pad>': 1, '<SOS>': 2, '<EOS>': 3, 'の': 4, 'は': 5, 'か': 6, 'に': 7, 'を': 8, 'て': 9, 'た': 10, 'です': 11, 'が': 12, 'ます': 13, 'し': 14, 'どこ': 15, 'ん': 16, 'で': 17, 'な': 18, 'どう': 19, 'いる': 20, 'と': 21, '何': 22, 'い': 23, 'だれ': 24, 'う': 25, 'こと': 26, 'だ': 27, 'あなた': 28, 'ない': 29, 'いつ': 30, 'する': 31, 'たち': 32, 'いい': 33, 'この': 34, 'つ': 35, 'も': 36, 'ある': 37, 'お': 38, 'から': 39, 'たら': 40, '私': 41, 'よ': 42, 'でしょ': 43, 'わたし': 44, '人': 45, 'だい': 46, 'それ': 47, 'ませ': 48, 'まし': 49, 'いただけ': 50, 'へ': 51, 'その': 52, 'どうして': 53, 'ね': 54, 'たい': 55, 'かしら': 56, 'だっ': 57, 'なぜ': 58, 'これ': 59, 'よう': 60, 'どんな': 61, 'だろ': 62, 'ここ': 63, 'さん': 64, 'くれ': 65, 'ば': 66, 'どの': 67, 'やっ': 68, 'あり': 69, 'もらえ': 70, '彼': 71, '行く': 72, '行っ': 73, '誰': 74, 'なっ': 75, 'って': 76, 'について': 77, 'まで': 78, 'ぼく': 79, '彼女': 80, 'れ': 81, '言っ': 82, '来': 83, 'あの': 84, 'でき': 85, 'くらい': 86, 'ご': 87, 'さ': 88, 'なかっ': 89, '行き': 90, '今': 91, 'どういう': 92, 'もの': 93, '時': 94, '自分': 95, '時間': 96, '君': 97, 'ため': 98, 'できる': 99, 'でし': 100, '1': 101, 'いかが': 102, '思い': 103, 'そう': 104, '教え': 105, 'くれる': 106, 'み': 107, 'わ': 108, '的': 109, 'かい': 110, '好き': 111, '見': 112, 'られ': 113, 'いっしょ': 114, 'お願い': 115, '仕事': 116, '日本': 117, '\u3000': 118, 'きみ': 119, 'き': 120, '話し': 121, '電話': 122, 'なり': 123, '先生': 124, 'アメリカ': 125, '新しい': 126, '…': 127, 'だけ': 128, '思う': 129, '持っ': 130, '日': 131, '次': 132, '写真': 133, 'いくら': 134, 'てる': 135, 'ほか': 136, 'そこ': 137, 'や': 138, '必要': 139, '知っ': 140, 'とき': 141, 'なく': 142, 'という': 143, 'ましょ': 144, 'られる': 145, '中': 146, '店': 147, 'なる': 148, '前': 149, '家': 150, '何で': 151, '意味': 152, '話': 153, 'じゃ': 154, '手': 155, '書い': 156, '食べ': 157, ' ': 158, 'すれ': 159, 'ところ': 160, '者': 161, 'ちゃん': 162, 'つもり': 163, 'でも': 164, '僕': 165, '映画': 166, '住ん': 167, 'ください': 168, 'ちょっと': 169, 'どちら': 170, 'もう少し': 171, 'もっと': 172, '始まる': 173, '彼ら': 174, '聞い': 175, 'どれ': 176, 'もう': 177, '女の子': 178, '思っ': 179, '練習': 180, '行か': 181, '見つけ': 182, '買っ': 183, 'くる': 184, 'けど': 185, 'よく': 186, 'メール': 187, '始め': 188, '智美': 189, 'そんな': 190, 'とても': 191, '説明': 192, 'ござる': 193, '帰っ': 194, '建て': 195, '部屋': 196, 'っけ': 197, 'べき': 198, 'みんな': 199, '入れ': 200, '出身': 201, '考え': 202, '2': 203, 'いつも': 204, 'お父さん': 205, '方': 206, '本': 207, '試合': 208, 'あっ': 209, 'いけ': 210, 'わかる': 211, 'ロボコーパス': 212, '両親': 213, '料理': 214, '来る': 215, 'そんなに': 216, 'なら': 217, 'なんで': 218, '最初': 219, 'こんな': 220, '問題': 221, '姉ちゃん': 222, '皆さん': 223, '見え': 224, '3': 225, 'あと': 226, 'なん': 227, 'れる': 228, 'パーティー': 229, '名前': 230, '旅行': 231, '最後': 232, '置い': 233, '翔': 234, 'いっ': 235, 'きょう': 236, 'しまっ': 237, 'また': 238, 'もう一度': 239, 'コンテスト': 240, '予定': 241, '伝え': 242, '作っ': 243, '場所': 244, '学校': 245, '尋ね': 246, '英語': 247, '食べる': 248, 'あれ': 249, 'いくつ': 250, 'として': 251, 'ふたり': 252, 'まだ': 253, '今日': 254, '元気': 255, '出': 256, '夏': 257, '席': 258, '本当に': 259, '祭': 260, 'あげ': 261, 'いったい': 262, 'こんなに': 263, 'さま': 264, 'す': 265, 'たり': 266, 'どなた': 267, 'より': 268, 'わかっ': 269, 'わかり': 270, 'コーヒー': 271, '公園': 272, '具体': 273, '出る': 274, '勉強': 275, '少し': 276, '結果': 277, '聞く': 278, '見せ': 279, '言う': 280, '週末': 281, '陽': 282, '駅': 283, 'しよ': 284, 'なけれ': 285, 'よい': 286, 'チョコレート': 287, '一': 288, '一緒': 289, '先輩': 290, '参加': 291, '年': 292, '感じ': 293, '感謝': 294, '買える': 295, '車': 296, 'あやめ': 297, 'うまく': 298, 'お母さん': 299, 'せ': 300, 'ほしい': 301, 'レッスン': 302, '助け': 303, '図書館': 304, '所': 305, '撮っ': 306, '様': 307, '物': 308, '着': 309, '競技': 310, '記事': 311, '部': 312, 'いちばん': 313, 'え': 314, 'これから': 315, 'ので': 316, 'ほう': 317, 'もらえる': 318, 'バッグ': 319, '会社': 320, '入っ': 321, '出発': 322, '向かっ': 323, '向こう': 324, '君たち': 325, '回': 326, '大きな': 327, '待っ': 328, '演奏': 329, '用': 330, '答え': 331, '見る': 332, '貸し': 333, '間': 334, '雄平': 335, '5': 336, 'いか': 337, 'いく': 338, 'うち': 339, 'かかっ': 340, 'それら': 341, 'みたい': 342, 'オープン': 343, 'レストラン': 344, '一体': 345, '今年': 346, '休暇': 347, '会議': 348, '劇': 349, '場合': 350, '屋': 351, '悪い': 352, '最も': 353, '朝食': 354, '欲しい': 355, '発表': 356, '読ん': 357, '質問' ...
# Counter({'の': 3882, 'は': 2976, 'か': 2472, 'に': 1992, 'を': 1740, 'て': 1724, 'た': 1535, 'です': 1210, 'が': 1041, 'ます': 817, 'し': 800, 'どこ': 799, 'ん': 754, 'で': 716, 'な': 693, 'どう': 676, 'いる': 572, 'と': 563, '何': 542, 'い': 484, 'だれ': 433, 'う': 400, 'こと': 355, 'だ': 351, 'あなた': 338, 'ない': 338, 'いつ': 295, 'する': 275, 'たち': 254, 'この': 240, 'いい': 240, 'つ': 226, 'も': 222, 'ある': 219, 'お': 218, 'から': 209, 'たら': 207, '私': 202, 'よ': 195, 'でしょ': 194, 'わたし': 193, '人': 190, 'だい': 181, 'それ': 180, 'ませ': 174, 'まし': 173, 'いただけ': 172, 'へ': 170, 'その': 169, 'どうして': 167, 'ね': 163, 'たい': 162, 'かしら': 154, 'だっ': 151, 'なぜ': 146, 'これ': 137, 'よう': 135, 'どんな': 124, 'だろ': 123, 'ここ': 120, 'さん': 118, 'くれ': 114, 'ば': 113, 'どの': 110, 'やっ': 108, 'あり': 107, 'もらえ': 107, '彼': 106, '行く': 105, '行っ': 103, '誰': 101, 'なっ': 100, 'って': 97, 'について': 93, 'まで': 93, 'ぼく': 87, '彼女': 86, 'れ': 84, '言っ': 83, '来': 81, 'あの': 80, 'でき': 80, 'さ': 78, 'ご': 78, 'くらい': 78, '行き': 77, 'なかっ': 77, '今': 76, 'もの': 75, 'どういう': 75, '時': 75, '自分': 74, '時間': 73, '君': 72, 'ため': 69, 'でし': 68, 'できる': 68, '1': 66, 'いかが': 66, '思い': 66, 'そう': 63, '教え': 63, 'くれる': 61, 'み': 61, '的': 59, 'わ': 59, 'かい': 58, '見': 58, '好き': 58, 'られ': 57, 'いっしょ': 56, 'お願い': 56, '仕事': 56, '日本': 55, '\u3000': 54, 'きみ': 53, 'き': 52, '電話': 51, '話し': 51, '先生': 50, 'なり': 50, 'アメリカ': 49, '新しい': 49, 'だけ': 48, '持っ': 48, '…': 48, '思う': 48, '次': 47, '日': 47, '写真': 46, 'てる': 45, 'いくら': 45, 'ほか': 44, 'そこ': 43, '必要': 43, '知っ': 43, 'や': 43, 'なく': 42, 'とき': 42, '店': 41, '中': 41, 'られる': 41, 'という': 41, 'ましょ': 41, '家': 40, 'なる': 40, '前': 40, '何で': 39, '意味': 39, '話': 38, '書い': 37, '手': 37, 'じゃ': 37, '食べ': 37, 'ところ': 36, 'すれ': 36, ' ': 36, '者': 36, 'ちゃん': 35, 'でも': 35, 'つもり': 35, '僕': 34, '映画': 34, '住ん': 33, 'どちら': 32, '始まる': 32, 'ちょっと': 32, '聞い': 32, '彼ら': 32, 'ください': 32, 'もっと': 32, 'もう少し': 32, 'もう': 31, '思っ': 31, '買っ': 31, '行か': 31, '練習': 31, '女の子': 31, '見つけ': 31, 'どれ': 31, '智美': 30, 'メール': 30, 'くる': 30, 'よく': 30, 'けど': 30, '始め': 30, 'とても': 29, 'そんな': 29, '説明': 29, '部屋': 28, 'ござる': 28, '建て': 28, '帰っ': 28, '考え': 27, '出身': 27, 'みんな': 27, '入れ': 27, 'っけ': 27, 'べき': 27, '方': 26, '試合': 26, 'いつも': 26, '2': 26, 'お父さん': 26, '本': 26, 'わかる': 25, 'あっ': 25, '来る': 25, 'ロボコーパス': 25, '両親': 25, 'いけ': 25, '料理': 25, 'そんなに': 24, 'なら': 24, 'なんで': 24, '最初': 23, '皆さん': 22, '問題': 22, '姉ちゃん': 22, 'こんな': 22, '見え': 22, 'あと': 21, 'パーティー': 21, '置い': 21, '3': 21, '名前': 21, 'れる': 21, 'なん': 21, '最後': 21, '翔': 21, '旅行': 21, '作っ': 20, 'しまっ': 20, '学校': 20, 'もう一度': 20, '英語': 20, '予定': 20, '場所': 20, '尋ね': 20, '食べる': 20, '伝え': 20, 'きょう': 20, 'いっ': 20, 'コンテスト': 20, 'また': 20, 'まだ': 19, 'ふたり': 19, 'あれ': 19, '祭': 19, '席': 19, '夏': 19, 'いくつ': 19, '今日': 19, '出': 19, 'として': 19, '元気': 19, '本当に': 19, '出る': 18, '公園': 18, '結果': 18, 'どなた': 18, '駅': 18, 'より': 18, '言う': 18, '勉強': 18, '見せ': 18, 'あげ': 18, 'こんなに': 18, 'たり': 18, '週末': 18, '少し': 18, '陽': 18, 'わかっ': 18, 'さま': 18, 'コーヒー': 18, '聞く': 18, 'いったい': 18, '具体': 18, 'す': 18, 'わかり': 18, '一緒': 17, '買える': 17, '感じ': 17, 'よい': 17, 'なけれ': 17, '感謝': 17, 'チョコレート': 17, '年': 17, 'しよ': 17, '参加': 17, '車': 17, '先輩': 17, '一': 17, '撮っ': 16, '様': 16, '競技': 16, 'あやめ': 16, '着': 16, 'ほしい': 16, '部': 16, '図書館': 16, 'せ': 16, 'うまく': 16, 'レッスン': 16, '記事': 16, '助け': 16, '物': 16, '所': 16, 'お母さん': 16, 'もらえる': 15, '大きな': 15, '向こう': 15, 'え': 15, '向かっ': 15, '貸し': 15, '用': 15, '会社': 15, 'これから': 15, 'ので': 15, '見る': 15, 'いちばん': 15, '答え': 15, '回': 15, '出発': 15, '君たち': 15, '雄平': 15, '間': 15, '入っ': 15, '待っ': 15, '演奏': 15, 'バッグ': 15, 'ほう': 15, '一体': 14, '最も': 14, '発表': 14, 'かかっ': 14, '場合': 14, '5': 14, '休暇': 14, '欲しい': 14, '読ん': 14, '朝食': 14, 'レストラン': 14, '質問': 14, 'それら': 14, '屋': 14, 'うち': 14, 'みたい': 14, '会議': 14, 'いく': 14, '今年': 14, '劇': 14, '悪い': 14, 'オープン': 14, 'いか': 14, '気に入っ': 13, '言い': 13, '調子': 13, 'ティノ': 13, '気分': 13, '家族': 13, '科学': 13, 'クリス': 13, 'そして': 13, '誘っ': 13, '重要': 13, '手伝っ': 13, 'かかり': 13, 'たくさん': 13, '目': 13, '多く': 13, '日曜日': 13, '歳': 13, '声': 13, '末': 13, 'オーディション': 13, 'ノート': 13, '同じ': 13, '土曜日': 13, '夜': 13, '送っ': 13, '10': 13, 'チーム': 13, '関係': 13, 'ルナ': 13, '確認' ...
# tensor([[ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#         [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#         [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#         ...,
#         [ 2.9401, -2.0819, -2.0512,  ...,  5.7535,  5.0954, -5.5815],
#         [ 2.6323, -2.4728, -2.4781,  ...,  5.5860,  5.0808, -5.1833],
#         [ 2.5718, -2.4647, -2.4616,  ...,  5.5590,  5.1111, -5.3450]])
# label : 4, data : ['だれ', 'が', '賞', 'を', '取る', 'かしら']
# label : 3, data : ['どこ', 'で', 'ネイル', 'を', 'やっ', 'て', 'もらえる', 'かしら']
# label : 4, data : ['厳しい', '時代', 'が', '一体', 'どこ', 'で', '終わり', 'を', '迎える', 'の', 'か', 'わかる', '人', 'など', 'いる', 'の', 'でしょ', 'う', 'か']
# label : 7, data : ['接続', 'を', '確認', 'し', 'て', 'いただけ', 'ます', 'か']
# label : 5, data : ['なぜ', 'ダフォディル', 'さん', 'あなた', 'は', 'ぼく', 'たち', 'の', 'ため', 'に', 'パンケーキ', 'を', '作っ', 'た', 'ん', 'です', 'か']
# label : 1, data : ['骨董', '店', 'は', 'どう', 'なっ', 'た', 'ん', 'です', 'か']
# label : 1, data : ['あなた', 'の', '読書', 'スタイル', 'で', 'その間', 'の', '最も', '大きな', '変化', 'は', '何', 'でし', 'た', 'か']
# label : 1, data : ['その', 'テスト', '何', '点', '取っ', 'た']
# label : 6, data : ['とても', '古い', 'お', '店']
# label : 4, data : ['その', '写真', 'は', 'だれ', 'が', '撮っ', 'た', 'の']

# %%
class LSTM_Classifier(nn.Module):
    def __init__(self, embedding_dim, hidden_dim, vocab_size, output_size, device = None, emb_vec = None):
        
        super(LSTM_Classifier, self).__init__()
        
        self.model_type = 'LSTM'
        self.embedding_dim = embedding_dim
        self.hidden_dim = hidden_dim
        self.vocab_size = vocab_size
        self.output_size = output_size
        self.device = device
        self.emb_vec = emb_vec

        # define model
        self.embedding_layer = nn.Embedding(self.vocab_size, self.embedding_dim)
        self.embedding_layer.weight.data.copy_(self.emb_vec)
        self.lstm_layer = nn.LSTM(self.embedding_dim, self.hidden_dim)
        self.hidden2out_layer = nn.Linear(self.hidden_dim, self.output_size)
        self.softmax = nn.LogSoftmax(dim=1)

    def init_hidden(self, batch_size):
        h0 = autograd.Variable(torch.randn(1, batch_size, self.hidden_dim))
        c0 = autograd.Variable(torch.randn(1, batch_size, self.hidden_dim))
        if self.device != None:
          h0 = h0.to(self.device)
          c0 = c0.to(self.device)
        return (h0, c0)

    def forward(self, batch):
        self.hidden = self.init_hidden(batch.size(-1))
        embeddings = self.embedding_layer(batch)
        #embeddings = embeddings.view(len(batch), 1, -1)
        lstm_out, (ht, ct) = self.lstm_layer(embeddings, self.hidden)
        # lstm_out = lstm_out[0].view(-1, self.hidden_dim)
        output = self.hidden2out_layer(ht[-1])
        output = self.softmax(output)

        return output

# %%
# 単語埋め込み次元
embedding_dim = 300
# LSTMの隠れ層の次元
hidden_dim = 128
# dataset全体の単語数
vocab_size = len(text_field.vocab)
# 予測class数
class_num = 9
# 学習係数 
lr = 0.001
# エポック数
epochs = 60
# model
model = LSTM_Classifier(embedding_dim, hidden_dim, vocab_size, class_num, device, text_field.vocab.vectors)
model.to(device)
# バッチサイズ
batch_size = 4
# loss func
criterion = torch.nn.CrossEntropyLoss().to(device)
# optimizer
optimizer = optim.Adam(model.parameters(), lr = lr)
# scheduler
# scheduler = torch.optim.lr_scheduler.StepLR(optimizer, 1, gamma=0.9)

# %%
def train_func(_train):
  model.train()   # modelを訓練モードに
  train_loss = 0.
  train_acc = 0.
  # mini-batch生成
  train_dataloader = torchtext.data.BucketIterator(
      _train,
      batch_size = batch_size,
      sort_key = lambda x: len(x.data),
      device = device,
      repeat = False
  )
  for batch in train_dataloader:
    text, label = batch.data, batch.label
    optimizer.zero_grad()
    output = model(text)
    loss = criterion(output, label)
    train_loss += loss.item()
    loss.backward()
    optimizer.step()
    train_acc += (output.argmax(1) == label).sum().item()
  return train_loss / len(_train), train_acc / len(_train) 


def evaluate_func(_test):
  model.eval()    # modelを推論モードに
  loss = 0.
  acc = 0.
  #mini-batch生成
  test_dataloader = torchtext.data.BucketIterator(
      test_dataset,
      batch_size = batch_size,
      sort_key = lambda x: len(x.data),
      device = device,
      repeat = False
  )
  for batch in test_dataloader:
    text, label = batch.data, batch.label
    with torch.no_grad():
      output = model(text)
      loss = criterion(output, label)
      loss += loss.item()
      acc += (output.argmax(1) == label).sum().item()
  return loss / len(_test), acc / len(_test)

for e in range(epochs):
  loss, acc = train_func(train_dataset)
  print('epoch : {}'.format(e))
  print('train_loss : {0}, train_acc : {1}'.format(loss, acc))

loss, acc = evaluate_func(test_dataset)
print('tes_loss : {0} test_acc : {1}'.format(loss, acc))
# Out:
# epoch : 0
# 0.5176109016041796 0.20470588235294118
# epoch : 1
# 0.4873287483824401 0.25563025210084034
# epoch : 2
# 0.47138992110220324 0.2752941176470588
# epoch : 3
# 0.4599766258231732 0.29126050420168065
# epoch : 4
# 0.42245340499557366 0.3665546218487395
# epoch : 5
# 0.36351098795898823 0.4403361344537815
# epoch : 6
# 0.32743947366706466 0.48369747899159665
# epoch : 7
# 0.3037175061547456 0.5126050420168067
# epoch : 8
# 0.29561591937261467 0.5324369747899159
# epoch : 9
# 0.27619129512239904 0.5621848739495798
# epoch : 10
# 0.26807599743624694 0.5726050420168067
# epoch : 11
# 0.25947954138286977 0.5905882352941176
# epoch : 12
# 0.2545074642956758 0.6020168067226891
# epoch : 13
# 0.24778911700644413 0.6152941176470588
# epoch : 14
# 0.24043824092743277 0.6238655462184874
# epoch : 15
# 0.24048581703307748 0.6284033613445378
# epoch : 16
# 0.23129674720663984 0.6534453781512605
# epoch : 17
# 0.21570071533823212 0.6831932773109244
# epoch : 18
# 0.20305475039141518 0.706890756302521
# epoch : 19
# 0.19070180424982133 0.7272268907563025
# epoch : 20
# 0.18823865533767253 0.733781512605042
# epoch : 21
# 0.177844723037311 0.7490756302521009
# epoch : 22
# 0.16914919316256027 0.7611764705882353
# epoch : 23
# 0.160031866470524 0.7685714285714286
# epoch : 24
# 0.1612736620251559 0.7697478991596639
# epoch : 25
# 0.15340500719183978 0.7863865546218487
# epoch : 26
# 0.15282273474654198 0.7877310924369748
# epoch : 27
# 0.14638244684764082 0.7910924369747899
# epoch : 28
# 0.14590457213537752 0.7941176470588235
# epoch : 29
# 0.14251093533353787 0.8008403361344538
# epoch : 30
# 0.14138990038677174 0.8084033613445378
# epoch : 31
# 0.1426556576212414 0.8015126050420168
# epoch : 32
# 0.13252586089278093 0.8154621848739496
# epoch : 33
# 0.13274509958257633 0.8151260504201681
# epoch : 34
# 0.1283510162494294 0.8161344537815126
# epoch : 35
# 0.12327058460841253 0.8265546218487395
# epoch : 36
# 0.12284627679457591 0.8235294117647058
# epoch : 37
# 0.11913522952895596 0.8305882352941176
# epoch : 38
# 0.11605405716167787 0.8369747899159664
# epoch : 39
# 0.1181740655061425 0.8270588235294117
# epoch : 40
# 0.1135038738513068 0.8388235294117647
# epoch : 41
# 0.11177082909259381 0.8440336134453782
# epoch : 42
# 0.10826274927021709 0.8485714285714285
# epoch : 43
# 0.10904703249312554 0.8423529411764706
# epoch : 44
# 0.1085103834143785 0.8447058823529412
# epoch : 45
# 0.10736550984262908 0.8499159663865546
# epoch : 46
# 0.11028827255054674 0.846218487394958
# epoch : 47
# 0.11710982296002458 0.8312605042016806
# epoch : 48
# 0.10531656131602016 0.8578151260504202
# epoch : 49
# 0.09609085127049001 0.8633613445378151
# epoch : 50
# 0.09769000955646517 0.858655462184874
# epoch : 51
# 0.09574085681048661 0.8660504201680672
# epoch : 52
# 0.09834618763431727 0.8611764705882353
# epoch : 53
# 0.095373968595948 0.865546218487395
# epoch : 54
# 0.09182118901362674 0.8707563025210084
# epoch : 55
# 0.08757330523237405 0.8749579831932773
# epoch : 56
# 0.0876856228564362 0.8768067226890757
# epoch : 57
# 0.08627753458430935 0.8771428571428571
# epoch : 58
# 0.08530415328660737 0.880672268907563
# epoch : 59
# 0.08249782051972775 0.8845378151260505
# tensor(0.0033, device='cuda:0') 0.6471774193548387
